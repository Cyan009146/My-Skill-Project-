# %% [markdown]
# # Feature Enginering

# %% [markdown]
# ## Import Module and Dataset

# %%
# Import modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data
data = pd.read_csv('ratings_small.csv')
data
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %% [markdown]
# ## Aggregate

# %% [markdown]
# ### Calculate aggregate values from ratings dataset

# %%
# Change data types of timestamp
pd.to_datetime(data['timestamp'], unit='s')
# Out:
# 0        2009-12-14 02:52:24
# 1        2009-12-14 02:52:59
# 2        2009-12-14 02:53:02
# 3        2009-12-14 02:53:05
# 4        2009-12-14 02:53:25
#                  ...
# 99999    2003-10-08 02:16:10
# 100000   2003-10-03 02:46:41
# 100001   2003-12-09 03:26:03
# 100002   2003-12-09 14:21:03
# 100003   2004-01-22 15:18:44
# Name: timestamp, Length: 100004, dtype: datetime64[ns]

# %%
# Check the result
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
# Checking duplicate values
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Now, we can make an aggregate value from table.
# In this section, we want to make the data one to many

# %%
# Check rating using mean
data.groupby('movieId')['rating'].mean()
# Out:
# movieId
# 1         3.872470
# 2         3.401869
# 3         3.161017
# 4         2.384615
# 5         3.267857
#             ...
# 161944    5.000000
# 162376    4.500000
# 162542    5.000000
# 162672    3.000000
# 163949    5.000000
# Name: rating, Length: 9066, dtype: float64

# %%
# Using aggregate function
data.groupby('movieId')['rating'].agg(['mean', 'median'])
# Out:
#              mean  median
# movieId
# 1        3.872470     4.0
# 2        3.401869     3.0
# 3        3.161017     3.0
# 4        2.384615     3.0
# 5        3.267857     3.0
# ...           ...     ...
# 161944   5.000000     5.0
# 162376   4.500000     4.5
# 162542   5.000000     5.0
# 162672   3.000000     3.0
# 163949   5.000000     5.0
#
# [9066 rows x 2 columns]

# %%
# Aggregate from 2 columns or more
data2 = data.groupby('movieId').agg({'userId' : pd.Series.nunique, 'rating' : ['mean', 'median']})
data2
# Out:
#          userId    rating
#         nunique      mean median
# movieId
# 1           247  3.872470    4.0
# 2           107  3.401869    3.0
# 3            59  3.161017    3.0
# 4            13  2.384615    3.0
# 5            56  3.267857    3.0
# ...         ...       ...    ...
# 161944        1  5.000000    5.0
# 162376        1  4.500000    4.5
# 162542        1  5.000000    5.0
# 162672        1  3.000000    3.0
# 163949        1  5.000000    5.0
#
# [9066 rows x 3 columns]

# %% [markdown]
# ## Join

# %% [markdown]
# There are five types of merging data, is:
# 1. Inner join
# 2. Outer Join
# 3. Left join
# 4. Right join
# 5. Cross join

# %% [markdown]
# ### Load Dataframe

# %%
# First, load movies_metadata
mov = pd.read_csv("movies_metadata.csv")
mov
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45458   True                                                NaN         0
# 45459   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459                      [{'id': 18, 'name': 'Drama'}]
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45458  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45459                                   NaN  111109  tt2028550
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45458                fa                      رگ خواب
# 45459                tl          Siglo ng Pagluluwal
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45458        Rising and falling between a man and woman.  ...           NaN
# 45459  An artist struggles to finish his work while a...  ...    2011-11-17
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45458          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45459          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45458  Released         Rising and falling between a man and woman
# 45459  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45458                       Subdue  False          4.0        1.0
# 45459          Century of Birthing  False          9.0        3.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [45463 rows x 24 columns]

# %% [markdown]
# ### Get Dataframe only english release languange

# %%
# Make a new dataset with english languange released
mov1 = mov[(mov["status"] == "Released") & (mov['original_language'] == 'en')]
mov1
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45456   True                                                NaN         0
# 45457   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45456           [{'id': 878, 'name': 'Science Fiction'}]
# 45457  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45456                                   NaN  222848  tt0112613
# 45457                                   NaN   30840  tt0102797
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45456                en              Caged Heat 3000
# 45457                en                   Robin Hood
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45456  It's the year 3000 AD. The world's most danger...  ...    1995-01-01
# 45457  Yet another version of the classic epic, with ...  ...    1991-05-13
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45456          0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45457          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45456  Released                                                NaN
# 45457  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45456              Caged Heat 3000  False          3.5        1.0
# 45457                   Robin Hood  False          5.7       26.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [31952 rows x 24 columns]

# %%
mov1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31952 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  31952 non-null  bool
#  1   belongs_to_collection  3099 non-null   object
#  2   budget                 31952 non-null  int64
#  3   genres                 31952 non-null  object
#  4   homepage               6103 non-null   object
#  5   id                     31952 non-null  int64
#  6   imdb_id                31941 non-null  object
#  7   original_language      31952 non-null  object
#  8   original_title         31952 non-null  object
#  9   overview               31888 non-null  object
#  10  popularity             31952 non-null  float64
#  11  poster_path            31641 non-null  object
#  12  production_companies   31952 non-null  object
#  13  production_countries   31952 non-null  object
#  14  release_date           31893 non-null  object
#  15  revenue                31952 non-null  float64
#  16  runtime                31946 non-null  float64
#  17  spoken_languages       31952 non-null  object
#  18  status                 31952 non-null  object
#  19  tagline                17830 non-null  object
#  20  title                  31952 non-null  object
#  21  video                  31952 non-null  bool
#  22  vote_average           31952 non-null  float64
#  23  vote_count             31952 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Merge Between movies rating and english released dataset

# %%
# Now, we want to merge movies rating and english released dataset
mov2 = mov1.merge(data, left_on = 'id', right_on = 'movieId', how ='inner')
mov2
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True                                                NaN  60000000
# 1       True                                                NaN  60000000
# 2       True                                                NaN  60000000
# 3       True                                                NaN  60000000
# 4       True                                                NaN  60000000
# ...      ...                                                ...       ...
# 33237   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33238   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33239   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33240   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33241   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
#
#                                                   genres homepage    id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 1      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 2      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 3      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 4      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# ...                                                  ...      ...   ...
# 33237  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33238  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33239  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33240  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33241  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
#
#          imdb_id original_language              original_title  \
# 0      tt0113277                en                        Heat
# 1      tt0113277                en                        Heat
# 2      tt0113277                en                        Heat
# 3      tt0113277                en                        Heat
# 4      tt0113277                en                        Heat
# ...          ...               ...                         ...
# 33237  tt0061683                en  Frankenstein Created Woman
# 33238  tt0061683                en  Frankenstein Created Woman
# 33239  tt0061683                en  Frankenstein Created Woman
# 33240  tt0061683                en  Frankenstein Created Woman
# 33241  tt0061683                en  Frankenstein Created Woman
#
#                                                 overview  ...    status  \
# 0      Obsessive master thief, Neil McCauley leads a ...  ...  Released
# 1      Obsessive master thief, Neil McCauley leads a ...  ...  Released
# 2      Obsessive master thief, Neil McCauley leads a ...  ...  Released
# 3      Obsessive master thief, Neil McCauley leads a ...  ...  Released
# 4      Obsessive master thief, Neil McCauley leads a ...  ...  Released
# ...                                                  ...  ...       ...
# 33237  A deformed tormented girl drowns herself after...  ...  Released
# 33238  A deformed tormented girl drowns herself after...  ...  Released
# 33239  A deformed tormented girl drowns herself after...  ...  Released
# 33240  A deformed tormented girl drowns herself after...  ...  Released
# 33241  A deformed tormented girl drowns herself after...  ...  Released
#
#                                                  tagline  \
# 0                               A Los Angeles Crime Saga
# 1                               A Los Angeles Crime Saga
# 2                               A Los Angeles Crime Saga
# 3                               A Los Angeles Crime Saga
# 4                               A Los Angeles Crime Saga
# ...                                                  ...
# 33237  Now Frankenstein has created a beautiful woman...
# 33238  Now Frankenstein has created a beautiful woman...
# 33239  Now Frankenstein has created a beautiful woman...
# 33240  Now Frankenstein has created a beautiful woman...
# 33241  Now Frankenstein has created a beautiful woman...
#
#                             title  video vote_average  vote_count  userId  \
# 0                            Heat  False          7.7      1886.0      23
# 1                            Heat  False          7.7      1886.0     102
# 2                            Heat  False          7.7      1886.0     232
# 3                            Heat  False          7.7      1886.0     242
# 4                            Heat  False          7.7      1886.0     263
# ...                           ...    ...          ...         ...     ...
# 33237  Frankenstein Created Woman  False          5.9        33.0     518
# 33238  Frankenstein Created Woman  False          5.9        33.0     547
# 33239  Frankenstein Created Woman  False          5.9        33.0     585
# 33240  Frankenstein Created Woman  False          5.9        33.0     624
# 33241  Frankenstein Created Woman  False          5.9        33.0     652
#
#       movieId rating   timestamp
# 0         949    3.5  1148721092
# 1         949    4.0   956598942
# 2         949    2.0   955092697
# 3         949    5.0   956688825
# 4         949    3.0  1117846575
# ...       ...    ...         ...
# 33237    3104    5.0   945363668
# 33238    3104    5.0   981312902
# 33239    3104    4.0   975362967
# 33240    3104    4.0  1019124279
# 33241    3104    4.0  1440269528
#
# [33242 rows x 28 columns]

# %%
# Get the info
mov2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33242 entries, 0 to 33241
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  33242 non-null  bool
#  1   belongs_to_collection  8670 non-null   object
#  2   budget                 33242 non-null  int64
#  3   genres                 33242 non-null  object
#  4   homepage               8430 non-null   object
#  5   id                     33242 non-null  int64
#  6   imdb_id                33242 non-null  object
#  7   original_language      33242 non-null  object
#  8   original_title         33242 non-null  object
#  9   overview               33237 non-null  object
#  10  popularity             33242 non-null  float64
#  11  poster_path            33207 non-null  object
#  12  production_companies   33242 non-null  object
#  13  production_countries   33242 non-null  object
#  14  release_date           33213 non-null  object
#  15  revenue                33242 non-null  float64
#  16  runtime                33242 non-null  float64
#  17  spoken_languages       33242 non-null  object
#  18  status                 33242 non-null  object
#  19  tagline                27367 non-null  object
#  20  title                  33242 non-null  object
#  21  video                  33242 non-null  bool
#  22  vote_average           33242 non-null  float64
#  23  vote_count             33242 non-null  float64
#  24  userId                 33242 non-null  int64
#  25  movieId                33242 non-null  int64
#  26  rating                 33242 non-null  float64
#  27  timestamp              33242 non-null  int64
# dtypes: bool(2), float64(6), int64(5), object(15)
# memory usage: 6.7+ MB

# %% [markdown]
# ## Feature Engineering

# %%
# Now, we want to make a feature engineering
mov2['profit'] = mov2['revenue'] - mov2['budget']
mov2
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True                                                NaN  60000000
# 1       True                                                NaN  60000000
# 2       True                                                NaN  60000000
# 3       True                                                NaN  60000000
# 4       True                                                NaN  60000000
# ...      ...                                                ...       ...
# 33237   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33238   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33239   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33240   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33241   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
#
#                                                   genres homepage    id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 1      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 2      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 3      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 4      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# ...                                                  ...      ...   ...
# 33237  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33238  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33239  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33240  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33241  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
#
#          imdb_id original_language              original_title  \
# 0      tt0113277                en                        Heat
# 1      tt0113277                en                        Heat
# 2      tt0113277                en                        Heat
# 3      tt0113277                en                        Heat
# 4      tt0113277                en                        Heat
# ...          ...               ...                         ...
# 33237  tt0061683                en  Frankenstein Created Woman
# 33238  tt0061683                en  Frankenstein Created Woman
# 33239  tt0061683                en  Frankenstein Created Woman
# 33240  tt0061683                en  Frankenstein Created Woman
# 33241  tt0061683                en  Frankenstein Created Woman
#
#                                                 overview  ...  \
# 0      Obsessive master thief, Neil McCauley leads a ...  ...
# 1      Obsessive master thief, Neil McCauley leads a ...  ...
# 2      Obsessive master thief, Neil McCauley leads a ...  ...
# 3      Obsessive master thief, Neil McCauley leads a ...  ...
# 4      Obsessive master thief, Neil McCauley leads a ...  ...
# ...                                                  ...  ...
# 33237  A deformed tormented girl drowns herself after...  ...
# 33238  A deformed tormented girl drowns herself after...  ...
# 33239  A deformed tormented girl drowns herself after...  ...
# 33240  A deformed tormented girl drowns herself after...  ...
# 33241  A deformed tormented girl drowns herself after...  ...
#
#                                                  tagline  \
# 0                               A Los Angeles Crime Saga
# 1                               A Los Angeles Crime Saga
# 2                               A Los Angeles Crime Saga
# 3                               A Los Angeles Crime Saga
# 4                               A Los Angeles Crime Saga
# ...                                                  ...
# 33237  Now Frankenstein has created a beautiful woman...
# 33238  Now Frankenstein has created a beautiful woman...
# 33239  Now Frankenstein has created a beautiful woman...
# 33240  Now Frankenstein has created a beautiful woman...
# 33241  Now Frankenstein has created a beautiful woman...
#
#                             title  video vote_average vote_count  userId  \
# 0                            Heat  False          7.7     1886.0      23
# 1                            Heat  False          7.7     1886.0     102
# 2                            Heat  False          7.7     1886.0     232
# 3                            Heat  False          7.7     1886.0     242
# 4                            Heat  False          7.7     1886.0     263
# ...                           ...    ...          ...        ...     ...
# 33237  Frankenstein Created Woman  False          5.9       33.0     518
# 33238  Frankenstein Created Woman  False          5.9       33.0     547
# 33239  Frankenstein Created Woman  False          5.9       33.0     585
# 33240  Frankenstein Created Woman  False          5.9       33.0     624
# 33241  Frankenstein Created Woman  False          5.9       33.0     652
#
#        movieId rating   timestamp       profit
# 0          949    3.5  1148721092  127436818.0
# 1          949    4.0   956598942  127436818.0
# 2          949    2.0   955092697  127436818.0
# 3          949    5.0   956688825  127436818.0
# 4          949    3.0  1117846575  127436818.0
# ...        ...    ...         ...          ...
# 33237     3104    5.0   945363668          0.0
# 33238     3104    5.0   981312902          0.0
# 33239     3104    4.0   975362967          0.0
# 33240     3104    4.0  1019124279          0.0
# 33241     3104    4.0  1440269528          0.0
#
# [33242 rows x 29 columns]

# %%
# Film that hte biggest profit
mov2[['original_title', 'profit']].sort_values('profit', ascending=False)
# Out:
#          original_title        profit
# 6744            Titanic  1.645034e+09
# 6771            Titanic  1.645034e+09
# 6779            Titanic  1.645034e+09
# 6778            Titanic  1.645034e+09
# 6777            Titanic  1.645034e+09
# ...                 ...           ...
# 11107  The 13th Warrior -9.830110e+07
# 11106  The 13th Warrior -9.830110e+07
# 11105  The 13th Warrior -9.830110e+07
# 11104  The 13th Warrior -9.830110e+07
# 11122  The 13th Warrior -9.830110e+07
#
# [33242 rows x 2 columns]

# %%
# Film more than 3 hours
mov2['long_duration_movie'] = mov2['runtime'] >= 180
mov2
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True                                                NaN  60000000
# 1       True                                                NaN  60000000
# 2       True                                                NaN  60000000
# 3       True                                                NaN  60000000
# 4       True                                                NaN  60000000
# ...      ...                                                ...       ...
# 33237   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33238   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33239   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33240   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 33241   True  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
#
#                                                   genres homepage    id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 1      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 2      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 3      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# 4      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   949
# ...                                                  ...      ...   ...
# 33237  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33238  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33239  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33240  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
# 33241  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  3104
#
#          imdb_id original_language              original_title  \
# 0      tt0113277                en                        Heat
# 1      tt0113277                en                        Heat
# 2      tt0113277                en                        Heat
# 3      tt0113277                en                        Heat
# 4      tt0113277                en                        Heat
# ...          ...               ...                         ...
# 33237  tt0061683                en  Frankenstein Created Woman
# 33238  tt0061683                en  Frankenstein Created Woman
# 33239  tt0061683                en  Frankenstein Created Woman
# 33240  tt0061683                en  Frankenstein Created Woman
# 33241  tt0061683                en  Frankenstein Created Woman
#
#                                                 overview  ...  \
# 0      Obsessive master thief, Neil McCauley leads a ...  ...
# 1      Obsessive master thief, Neil McCauley leads a ...  ...
# 2      Obsessive master thief, Neil McCauley leads a ...  ...
# 3      Obsessive master thief, Neil McCauley leads a ...  ...
# 4      Obsessive master thief, Neil McCauley leads a ...  ...
# ...                                                  ...  ...
# 33237  A deformed tormented girl drowns herself after...  ...
# 33238  A deformed tormented girl drowns herself after...  ...
# 33239  A deformed tormented girl drowns herself after...  ...
# 33240  A deformed tormented girl drowns herself after...  ...
# 33241  A deformed tormented girl drowns herself after...  ...
#
#                             title  video vote_average vote_count userId  \
# 0                            Heat  False          7.7     1886.0     23
# 1                            Heat  False          7.7     1886.0    102
# 2                            Heat  False          7.7     1886.0    232
# 3                            Heat  False          7.7     1886.0    242
# 4                            Heat  False          7.7     1886.0    263
# ...                           ...    ...          ...        ...    ...
# 33237  Frankenstein Created Woman  False          5.9       33.0    518
# 33238  Frankenstein Created Woman  False          5.9       33.0    547
# 33239  Frankenstein Created Woman  False          5.9       33.0    585
# 33240  Frankenstein Created Woman  False          5.9       33.0    624
# 33241  Frankenstein Created Woman  False          5.9       33.0    652
#
#        movieId  rating   timestamp       profit long_duration_movie
# 0          949     3.5  1148721092  127436818.0               False
# 1          949     4.0   956598942  127436818.0               False
# 2          949     2.0   955092697  127436818.0               False
# 3          949     5.0   956688825  127436818.0               False
# 4          949     3.0  1117846575  127436818.0               False
# ...        ...     ...         ...          ...                 ...
# 33237     3104     5.0   945363668          0.0               False
# 33238     3104     5.0   981312902          0.0               False
# 33239     3104     4.0   975362967          0.0               False
# 33240     3104     4.0  1019124279          0.0               False
# 33241     3104     4.0  1440269528          0.0               False
#
# [33242 rows x 30 columns]

# %%
mov2['title_length'] = mov2['original_title'].str.len()
mov2['title_length'] < 10
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 33237    False
# 33238    False
# 33239    False
# 33240    False
# 33241    False
# Name: title_length, Length: 33242, dtype: bool

# %%
# Make length of original_title
count_list = []
for i in range(len(mov2)):
    count = len(mov2['title'][i])
    count_list.append(count)

mov2['title_len'] = count_list
mov2['title_len']
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 33237    26
# 33238    26
# 33239    26
# 33240    26
# 33241    26
# Name: title_len, Length: 33242, dtype: int64

# %%
# Make runtime column from minutes to hours
mov2['duration_hours'] = pd.to_datetime(mov2.runtime, unit='m').dt.strftime('%H:%M')
mov2['duration_hours']
# Out:
# 0        02:50
# 1        02:50
# 2        02:50
# 3        02:50
# 4        02:50
#          ...
# 33237    01:32
# 33238    01:32
# 33239    01:32
# 33240    01:32
# 33241    01:32
# Name: duration_hours, Length: 33242, dtype: object
