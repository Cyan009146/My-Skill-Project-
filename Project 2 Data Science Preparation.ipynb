# %% [markdown]
# # Data Science Preparation

# %% [markdown]
# ## Import Modules and Change Data Type

# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load dataset. We will use movies_metadata.csv
data = pd.read_csv('movies_metadata.csv')
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45458   True                                                NaN         0
# 45459   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459                      [{'id': 18, 'name': 'Drama'}]
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45458  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45459                                   NaN  111109  tt2028550
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45458                fa                      رگ خواب
# 45459                tl          Siglo ng Pagluluwal
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45458        Rising and falling between a man and woman.  ...           NaN
# 45459  An artist struggles to finish his work while a...  ...    2011-11-17
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45458          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45459          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45458  Released         Rising and falling between a man and woman
# 45459  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45458                       Subdue  False          4.0        1.0
# 45459          Century of Birthing  False          9.0        3.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [45463 rows x 24 columns]

# %%
# Check data types
data.dtypes
# Out:
# adult                       bool
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                       bool
# vote_average             float64
# vote_count               float64
# dtype: object

# %% [markdown]
# ### Change Data Type

# %%
# Now we wat to change release dato from object to datetime
# First, we need to check the format of the date
data['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45458           NaN
# 45459    2011-11-17
# 45460    2003-08-01
# 45461    1917-10-21
# 45462    2017-06-09
# Name: release_date, Length: 45463, dtype: object

# %%
# Change the data type
data['release_date'] = pd.to_datetime(data['release_date'])
data['release_date'].dtypes
data.dtypes
# Out:
# adult                              bool
# belongs_to_collection            object
# budget                            int64
# genres                           object
# homepage                         object
# id                                int64
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                      float64
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                              bool
# vote_average                    float64
# vote_count                      float64
# dtype: object

# %%
# Check the data again
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45458   True                                                NaN         0
# 45459   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459                      [{'id': 18, 'name': 'Drama'}]
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45458  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45459                                   NaN  111109  tt2028550
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45458                fa                      رگ خواب
# 45459                tl          Siglo ng Pagluluwal
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45458        Rising and falling between a man and woman.  ...           NaT
# 45459  An artist struggles to finish his work while a...  ...    2011-11-17
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45458          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45459          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45458  Released         Rising and falling between a man and woman
# 45459  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45458                       Subdue  False          4.0        1.0
# 45459          Century of Birthing  False          9.0        3.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [45463 rows x 24 columns]

# %% [markdown]
# So, in this section we change data types to what we desire and ensure data type is correct.

# %% [markdown]
# Now, we check data values which is unique

# %%
# Check status data values
data['status'].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
# Check language data values
data['original_language'].unique()
data['original_language'].nunique()
# Out:
# 89

# %% [markdown]
# ## Filter

# %% [markdown]
# In this section, we want to filter data based on values in data

# %%
# Check the movies that is released
data['status'] == 'released'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45458    False
# 45459    False
# 45460    False
# 45461    False
# 45462    False
# Name: status, Length: 45463, dtype: bool

# %%
# Check the movies with original language is english
data['original_language'] == 'en'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 45458    False
# 45459    False
# 45460     True
# 45461     True
# 45462     True
# Name: original_language, Length: 45463, dtype: bool

# %%
# Check movies that are released and original language is english
(data['status'] == 'Released') & (data['original_language'] == 'en')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 45458    False
# 45459    False
# 45460     True
# 45461     True
# 45462     True
# Length: 45463, dtype: bool

# %%
# Set the data for further analysis
data1 = data[(data['status'] == 'Released') & (data['original_language'] == 'en')]
data1
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45456   True                                                NaN         0
# 45457   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45456           [{'id': 878, 'name': 'Science Fiction'}]
# 45457  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45456                                   NaN  222848  tt0112613
# 45457                                   NaN   30840  tt0102797
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45456                en              Caged Heat 3000
# 45457                en                   Robin Hood
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45456  It's the year 3000 AD. The world's most danger...  ...    1995-01-01
# 45457  Yet another version of the classic epic, with ...  ...    1991-05-13
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45456          0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45457          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45456  Released                                                NaN
# 45457  Released                                                NaN
# 45460  Released                             A deadly game of wits.
# 45461  Released                                                NaN
# 45462  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45456              Caged Heat 3000  False          3.5        1.0
# 45457                   Robin Hood  False          5.7       26.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [31952 rows x 24 columns]

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### Sort The Data With One and Two Variables

# %% [markdown]
# We can use ascending or descending sort

# %%
# Sort the data by budget column
data_sort1 = data1.sort_values(by='budget', ascending=False)
data_sort1
# Out:
#        adult                              belongs_to_collection     budget  \
# 17124   True  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827   True  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557   True  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# 11067   True  {'id': 8537, 'name': 'Superman Collection', 'p...  270000000
# 18685   True                                                NaN  260000000
# ...      ...                                                ...        ...
# 17256   True                                                NaN          0
# 17255   True                                                NaN          0
# 17254   True                                                NaN          0
# 17252   True                                                NaN          0
# 45462   True                                                NaN          0
#
#                                                   genres  \
# 17124  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 11827  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 26557  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11067  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 18685  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...                                                  ...
# 17256                                                 []
# 17255  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 17254                                                 []
# 17252                [{'id': 99, 'name': 'Documentary'}]
# 45462                                                 []
#
#                                                 homepage      id    imdb_id  \
# 17124  http://disney.go.com/pirates/index-on-stranger...    1865  tt1298650
# 11827       http://disney.go.com/disneypictures/pirates/     285  tt0449088
# 26557  http://marvel.com/movies/movie/193/avengers_ag...   99861  tt2395427
# 11067                            http://www.superman.com    1452  tt0348150
# 18685               http://movies.disney.com/john-carter   49529  tt0401729
# ...                                                  ...     ...        ...
# 17256                                                NaN  449677  tt0446510
# 17255                                                NaN  222600  tt0076374
# 17254                                                NaN  140007  tt0264378
# 17252                                                NaN   34835  tt1590078
# 45462                                                NaN  461257  tt6980792
#
#       original_language                               original_title  \
# 17124                en  Pirates of the Caribbean: On Stranger Tides
# 11827                en     Pirates of the Caribbean: At World's End
# 26557                en                      Avengers: Age of Ultron
# 11067                en                             Superman Returns
# 18685                en                                  John Carter
# ...                 ...                                          ...
# 17256                en               The Year of Living Vicariously
# 17255                en                                      Matinée
# 17254                en                      Après la réconciliation
# 17252                en                          It Felt Like a Kiss
# 45462                en                                     Queerama
#
#                                                 overview  ...  release_date  \
# 17124  Captain Jack Sparrow crosses paths with a woma...  ...    2011-05-14
# 11827  Captain Barbossa, long believed to be dead, ha...  ...    2007-05-19
# 26557  When Tony Stark tries to jumpstart a dormant p...  ...    2015-04-22
# 11067  Superman returns to discover his 5-year absenc...  ...    2006-06-28
# 18685  John Carter is a war-weary, former military ca...  ...    2012-03-07
# ...                                                  ...  ...           ...
# 17256  This split-screen documentary by a Malaysian d...  ...    2005-01-23
# 17255  Jorge and Aarón, two young boys growing up in ...  ...    1977-09-18
# 17254  An elderly couple and a younger man and woman ...  ...    2000-12-27
# 17252  The story of America's rise to power starting ...  ...    2009-01-01
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#             revenue runtime  \
# 17124  1.045714e+09   136.0
# 11827  9.610000e+08   169.0
# 26557  1.405404e+09   141.0
# 11067  3.910812e+08   154.0
# 18685  2.841391e+08   132.0
# ...             ...     ...
# 17256  0.000000e+00    63.0
# 17255  0.000000e+00    98.0
# 17254  0.000000e+00    74.0
# 17252  0.000000e+00    54.0
# 45462  0.000000e+00    75.0
#
#                                         spoken_languages    status  \
# 17124  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 11827           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 26557           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11067  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 18685           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 17256                                                 []  Released
# 17255           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 17254          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 17252           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45462           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 17124                     Live Forever Or Die Trying.
# 11827  At the end of the world, the adventure begins.
# 26557                             A New Age Has Come.
# 11067                                             NaN
# 18685            Lost in our world, found in another.
# ...                                               ...
# 17256                                             NaN
# 17255                                             NaN
# 17254                                             NaN
# 17252                                             NaN
# 45462                                             NaN
#
#                                              title  video vote_average  \
# 17124  Pirates of the Caribbean: On Stranger Tides  False          6.4
# 11827     Pirates of the Caribbean: At World's End  False          6.9
# 26557                      Avengers: Age of Ultron  False          7.3
# 11067                             Superman Returns  False          5.4
# 18685                                  John Carter  False          6.1
# ...                                            ...    ...          ...
# 17256               The Year of Living Vicariously  False          5.0
# 17255                                      Matinée  False          6.3
# 17254                     After the Reconciliation  False          8.0
# 17252                          It Felt Like a Kiss  False          6.9
# 45462                                     Queerama  False          0.0
#
#       vote_count
# 17124     5068.0
# 11827     4627.0
# 26557     6908.0
# 11067     1429.0
# 18685     2170.0
# ...          ...
# 17256        1.0
# 17255        2.0
# 17254        1.0
# 17252        7.0
# 45462        0.0
#
# [31952 rows x 24 columns]

# %%
# Now, we sort the data by revenue and budget
data_sort2 = data1.sort_values(by=['revenue', 'budget'], ascending=False)
data_sort2
# Out:
#        adult                              belongs_to_collection     budget  \
# 14551   True  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 26554   True  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 1639    True                                                NaN  200000000
# 17818   True  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 25083   True  {'id': 328, 'name': 'Jurassic Park Collection'...  150000000
# ...      ...                                                ...        ...
# 45456   True                                                NaN          0
# 45457   True                                                NaN          0
# 45460   True                                                NaN          0
# 45461   True                                                NaN          0
# 45462   True                                                NaN          0
#
#                                                   genres  \
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 26554  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1639   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17818  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 25083  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...                                                  ...
# 45456           [{'id': 878, 'name': 'Science Fiction'}]
# 45457  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                                 homepage      id    imdb_id  \
# 14551                        http://www.avatarmovie.com/   19995  tt0499549
# 26554  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 1639                         http://www.titanicmovie.com     597  tt0120338
# 17818                  http://marvel.com/avengers_movie/   24428  tt0848228
# 25083                      http://www.jurassicworld.com/  135397  tt0369610
# ...                                                  ...     ...        ...
# 45456                                                NaN  222848  tt0112613
# 45457                                                NaN   30840  tt0102797
# 45460                                                NaN   67758  tt0303758
# 45461                                                NaN  227506  tt0008536
# 45462                                                NaN  461257  tt6980792
#
#       original_language                original_title  \
# 14551                en                        Avatar
# 26554                en  Star Wars: The Force Awakens
# 1639                 en                       Titanic
# 17818                en                  The Avengers
# 25083                en                Jurassic World
# ...                 ...                           ...
# 45456                en               Caged Heat 3000
# 45457                en                    Robin Hood
# 45460                en                      Betrayal
# 45461                en           Satana likuyushchiy
# 45462                en                      Queerama
#
#                                                 overview  ...  release_date  \
# 14551  In the 22nd century, a paraplegic Marine is di...  ...    2009-12-10
# 26554  Thirty years after defeating the Galactic Empi...  ...    2015-12-15
# 1639   84 years later, a 101-year-old woman named Ros...  ...    1997-11-18
# 17818  When an unexpected enemy emerges and threatens...  ...    2012-04-25
# 25083  Twenty-two years after the events of Jurassic ...  ...    2015-06-09
# ...                                                  ...  ...           ...
# 45456  It's the year 3000 AD. The world's most danger...  ...    1995-01-01
# 45457  Yet another version of the classic epic, with ...  ...    1991-05-13
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#             revenue runtime  \
# 14551  2.787965e+09   162.0
# 26554  2.068224e+09   136.0
# 1639   1.845034e+09   194.0
# 17818  1.519558e+09   143.0
# 25083  1.513529e+09   124.0
# ...             ...     ...
# 45456  0.000000e+00    85.0
# 45457  0.000000e+00   104.0
# 45460  0.000000e+00    90.0
# 45461  0.000000e+00    87.0
# 45462  0.000000e+00    75.0
#
#                                         spoken_languages    status  \
# 14551  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 26554           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1639   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 17818           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 25083           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45456           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45457           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45461                                                 []  Released
# 45462           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                          tagline  \
# 14551                Enter the World of Pandora.
# 26554              Every generation has a story.
# 1639   Nothing on Earth could come between them.
# 17818                    Some assembly required.
# 25083                          The park is open.
# ...                                          ...
# 45456                                        NaN
# 45457                                        NaN
# 45460                     A deadly game of wits.
# 45461                                        NaN
# 45462                                        NaN
#
#                               title  video vote_average vote_count
# 14551                        Avatar  False          7.2    12114.0
# 26554  Star Wars: The Force Awakens  False          7.5     7993.0
# 1639                        Titanic  False          7.5     7770.0
# 17818                  The Avengers  False          7.4    12000.0
# 25083                Jurassic World  False          6.5     8842.0
# ...                             ...    ...          ...        ...
# 45456               Caged Heat 3000  False          3.5        1.0
# 45457                    Robin Hood  False          5.7       26.0
# 45460                      Betrayal  False          3.8        6.0
# 45461              Satan Triumphant  False          0.0        0.0
# 45462                      Queerama  False          0.0        0.0
#
# [31952 rows x 24 columns]

# %% [markdown]
# ## Handling Duplicate Values

# %% [markdown]
# In this section, we calculate and remove any duplicate values from the dataset.

# %%
# Now, let's check for duplicate values
data1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45456    False
# 45457    False
# 45460    False
# 45461    False
# 45462    False
# Length: 31952, dtype: bool

# %%
# Sum of duplicate values
data1.duplicated().sum()
# Out:
# np.int64(9)

# %%
# Check duplicate values from specific columns
dup1 = data1[data1.duplicated(subset=['original_title', 'release_date'], keep=False)].sort_values("original_title")
dup1
# Out:
#        adult                              belongs_to_collection    budget  \
# 949     True                                                NaN         4
# 15074   True                                                NaN         4
# 2564    True                                                NaN         0
# 21115   True                                                NaN         0
# 20842   True                                                NaN  40000000
# 11155   True                                                NaN  40000000
# 10419   True                                                NaN   1600000
# 12066   True                                                NaN   1600000
# 33741   True                                                NaN  26000000
# 5130    True                                                NaN  26000000
# 33824   True                                                NaN  30000000
# 5865    True                                                NaN  30000000
# 22150   True                                                NaN         0
# 14000   True                                                NaN         0
# 24843   True                                                NaN         0
# 14012   True                                                NaN         0
# 13603   True                                                NaN         0
# 28859   True                                                NaN         0
# 20898   True                                                NaN         0
# 5710    True                                                NaN         0
# 40273   True                                                NaN         0
# 13946   True                                                NaN         0
# 21853   True                                                NaN         0
# 19924   True                                                NaN         0
# 26624   True                                                NaN  10000000
# 9576    True                                                NaN  10000000
# 19889   True                                                NaN         0
# 21164   True                                                NaN         0
# 38868   True                                                NaN         0
# 16167   True                                                NaN         0
# 9327    True                                                NaN         0
# 8068    True                                                NaN         0
# 13220   True  {'id': 158365, 'name': 'Why We Fight', 'poster...         0
# 35795   True  {'id': 158365, 'name': 'Why We Fight', 'poster...         0
#
#                                                   genres  \
# 949    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 15074  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2564                 [{'id': 99, 'name': 'Documentary'}]
# 21115                [{'id': 99, 'name': 'Documentary'}]
# 20842  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 11155  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 10419  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 12066  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 33741  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 5130   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33824  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 5865   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 22150  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 14000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 24843  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 14012  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 13603  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 28859  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 20898                      [{'id': 18, 'name': 'Drama'}]
# 5710                       [{'id': 18, 'name': 'Drama'}]
# 40273                     [{'id': 35, 'name': 'Comedy'}]
# 13946                     [{'id': 35, 'name': 'Comedy'}]
# 21853  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 19924  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 26624  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 9576   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 19889  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 21164  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 38868  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 16167  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 8068   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 13220                [{'id': 99, 'name': 'Documentary'}]
# 35795                [{'id': 99, 'name': 'Documentary'}]
#
#                                      homepage      id    imdb_id  \
# 949                                       NaN   22649  tt0022879
# 15074                                     NaN   22649  tt0022879
# 2564                                      NaN   84198  tt1736049
# 21115                                     NaN   84198  tt1736049
# 20842                                     NaN   77221  tt1701210
# 11155                                     NaN   77221  tt1701210
# 10419           http://www.bubblethefilm.com/   14788  tt0454792
# 12066           http://www.bubblethefilm.com/   14788  tt0454792
# 33741                                     NaN   15028  tt0157472
# 5130                                      NaN   15028  tt0157472
# 33824                                     NaN    4912  tt0270288
# 5865                                      NaN    4912  tt0270288
# 22150  http://www.daysofdarknessthemovie.com/   18440  tt0499456
# 14000  http://www.daysofdarknessthemovie.com/   18440  tt0499456
# 24843            http://www.dealthemovie.com/   11115  tt0446676
# 14012            http://www.dealthemovie.com/   11115  tt0446676
# 13603                                     NaN  168538  tt0084387
# 28859                                     NaN  168538  tt0084387
# 20898                                     NaN  109962  tt0082992
# 5710                                      NaN  109962  tt0082992
# 40273                                     NaN   97995  tt0127834
# 13946                                     NaN   97995  tt0127834
# 21853                                     NaN  152795  tt1821641
# 19924                                     NaN  152795  tt1821641
# 26624                                     NaN   69234  tt0100361
# 9576                                      NaN   69234  tt0100361
# 19889                                     NaN  119916  tt0080000
# 21164                                     NaN  119916  tt0080000
# 38868                                     NaN   99080  tt0022537
# 16167                                     NaN   99080  tt0022537
# 9327                                      NaN   23305  tt0295682
# 8068                                      NaN   23305  tt0295682
# 13220                                     NaN  159849  tt0173769
# 35795                                     NaN  159849  tt0173769
#
#       original_language                    original_title  \
# 949                  en                A Farewell to Arms
# 15074                en                A Farewell to Arms
# 2564                 en              A Place at the Table
# 21115                en              A Place at the Table
# 20842                en                        Black Gold
# 11155                en                        Black Gold
# 10419                en                            Bubble
# 12066                en                            Bubble
# 33741                en                     Clockstoppers
# 5130                 en                     Clockstoppers
# 33824                en   Confessions of a Dangerous Mind
# 5865                 en   Confessions of a Dangerous Mind
# 22150                en                  Days of Darkness
# 14000                en                  Days of Darkness
# 24843                en                              Deal
# 14012                en                              Deal
# 13603                en                              Nana
# 28859                en                              Nana
# 20898                en                   Rich and Famous
# 5710                 en                   Rich and Famous
# 40273                en              Seven Years Bad Luck
# 13946                en              Seven Years Bad Luck
# 21853                en                      The Congress
# 19924                en                      The Congress
# 26624                en          The Phantom of the Opera
# 9576                 en          The Phantom of the Opera
# 19889                en                       The Tempest
# 21164                en                       The Tempest
# 38868                en                        The Viking
# 16167                en                        The Viking
# 9327                 en                       The Warrior
# 8068                 en                       The Warrior
# 13220                en  Why We Fight: Divide and Conquer
# 35795                en  Why We Fight: Divide and Conquer
#
#                                                 overview  ...  release_date  \
# 949    British nurse Catherine Barkley (Helen Hayes) ...  ...    1932-12-08
# 15074  British nurse Catherine Barkley (Helen Hayes) ...  ...    1932-12-08
# 2564   Using personal stories, this powerful document...  ...    2012-03-22
# 21115  Using personal stories, this powerful document...  ...    2012-03-22
# 20842  On the Arabian Peninsula in the 1930s, two war...  ...    2011-12-21
# 11155  On the Arabian Peninsula in the 1930s, two war...  ...    2011-12-21
# 10419  Set against the backdrop of a decaying Midwest...  ...    2005-09-03
# 12066  Set against the backdrop of a decaying Midwest...  ...    2005-09-03
# 33741  Until now, Zak Gibbs' greatest challenge has b...  ...    2002-03-17
# 5130   Until now, Zak Gibbs' greatest challenge has b...  ...    2002-03-17
# 33824  Television made him famous, but his biggest hi...  ...    2002-12-30
# 5865   Television made him famous, but his biggest hi...  ...    2002-12-30
# 22150  When a comet strikes Earth and kicks up a clou...  ...    2007-01-01
# 14000  When a comet strikes Earth and kicks up a clou...  ...    2007-01-01
# 24843  As an ex-gambler teaches a hot-shot college ki...  ...    2008-01-29
# 14012  As an ex-gambler teaches a hot-shot college ki...  ...    2008-01-29
# 13603  In Zola's Paris, an ingenue arrives at a tony ...  ...    1983-06-13
# 28859  In Zola's Paris, an ingenue arrives at a tony ...  ...    1983-06-13
# 20898  Two literary women compete for 20 years: one w...  ...    1981-09-23
# 5710   Two literary women compete for 20 years: one w...  ...    1981-09-23
# 40273  After breaking a mirror in his home, superstit...  ...    1921-02-06
# 13946  After breaking a mirror in his home, superstit...  ...    1921-02-06
# 21853  More than two decades after catapulting to sta...  ...    2013-05-16
# 19924  More than two decades after catapulting to sta...  ...    2013-05-16
# 26624  Count de Chagnie has discovered Christine's si...  ...    1990-03-18
# 9576   Count de Chagnie has discovered Christine's si...  ...    1990-03-18
# 19889  Prospero, the true Duke of Milan is now living...  ...    1980-02-27
# 21164  Prospero, the true Duke of Milan is now living...  ...    1980-02-27
# 38868  Originally called White Thunder, American prod...  ...    1931-06-21
# 16167  Originally called White Thunder, American prod...  ...    1931-06-21
# 9327   In feudal India, a warrior (Khan) who renounce...  ...    2001-09-23
# 8068   In feudal India, a warrior (Khan) who renounce...  ...    2001-09-23
# 13220  The third film of Frank Capra's 'Why We Fight"...  ...    1943-01-01
# 35795  The third film of Frank Capra's 'Why We Fight"...  ...    1943-01-01
#
#           revenue runtime                                   spoken_languages  \
# 949          25.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 15074        25.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2564          0.0    84.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 21115         0.0    84.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20842   5446000.0   130.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11155   5446000.0   130.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10419         0.0    73.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 12066         0.0    73.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 33741  38793283.0    94.0  [{'iso_639_1': 'cs', 'name': 'Český'}, {'iso_6...
# 5130   38793283.0    94.0  [{'iso_639_1': 'cs', 'name': 'Český'}, {'iso_6...
# 33824  33013805.0   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5865   33013805.0   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22150         0.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14000         0.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 24843         0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14012         0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13603         0.0    92.0                                                 []
# 28859         0.0    92.0                                                 []
# 20898         0.0   115.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5710          0.0   115.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40273         0.0    62.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13946         0.0    62.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 21853    455815.0   122.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19924    455815.0   122.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 26624         0.0   168.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 9576          0.0   168.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 19889         0.0   123.0                                                 []
# 21164         0.0   123.0                                                 []
# 38868         0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 16167         0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9327          0.0    86.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 8068          0.0    86.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 13220         0.0    57.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 35795         0.0    57.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 949    Released          Every woman who has loved will understand
# 15074  Released          Every woman who has loved will understand
# 2564   Released                              One Nation. Underfed.
# 21115  Released                              One Nation. Underfed.
# 20842  Released                                                NaN
# 11155  Released                                                NaN
# 10419  Released                                                NaN
# 12066  Released                                                NaN
# 33741  Released  The adventure of a lifetime, in a few mere sec...
# 5130   Released  The adventure of a lifetime, in a few mere sec...
# 33824  Released            Some things are better left top secret.
# 5865   Released            Some things are better left top secret.
# 22150  Released                                                NaN
# 14000  Released                                                NaN
# 24843  Released                                                NaN
# 14012  Released                                                NaN
# 13603  Released                                                NaN
# 28859  Released                                                NaN
# 20898  Released  From the very beginning, they knew they'd be f...
# 5710   Released  From the very beginning, they knew they'd be f...
# 40273  Released                                                NaN
# 13946  Released                                                NaN
# 21853  Released                                                NaN
# 19924  Released                                                NaN
# 26624  Released                                                NaN
# 9576   Released                                                NaN
# 19889  Released                                                NaN
# 21164  Released                                                NaN
# 38868  Released  Actually produced during the Great Newfoundlan...
# 16167  Released  Actually produced during the Great Newfoundlan...
# 9327   Released                                                NaN
# 8068   Released                                                NaN
# 13220  Released                                                NaN
# 35795  Released                                                NaN
#
#                                   title  video vote_average vote_count
# 949                  A Farewell to Arms  False          6.2       29.0
# 15074                A Farewell to Arms  False          6.2       29.0
# 2564               A Place at the Table  False          6.9        7.0
# 21115              A Place at the Table  False          6.9        7.0
# 20842                        Black Gold  False          5.9       77.0
# 11155                        Black Gold  False          5.9       77.0
# 10419                            Bubble  False          6.4       36.0
# 12066                            Bubble  False          6.4       36.0
# 33741                     Clockstoppers  False          4.9       90.0
# 5130                      Clockstoppers  False          4.9       89.0
# 33824   Confessions of a Dangerous Mind  False          6.6      281.0
# 5865    Confessions of a Dangerous Mind  False          6.6      281.0
# 22150                  Days of Darkness  False          5.0        5.0
# 14000                  Days of Darkness  False          5.0        5.0
# 24843                              Deal  False          5.2       22.0
# 14012                              Deal  False          5.2       22.0
# 13603    Nana, the True Key of Pleasure  False          4.7        3.0
# 28859    Nana, the True Key of Pleasure  False          4.7        3.0
# 20898                   Rich and Famous  False          4.9        7.0
# 5710                    Rich and Famous  False          4.9        7.0
# 40273              Seven Years Bad Luck  False          5.6        4.0
# 13946              Seven Years Bad Luck  False          5.6        4.0
# 21853                      The Congress  False          6.4      165.0
# 19924                      The Congress  False          6.4      165.0
# 26624          The Phantom of the Opera  False          5.0        3.0
# 9576           The Phantom of the Opera  False          5.0        3.0
# 19889                       The Tempest  False          0.0        0.0
# 21164                       The Tempest  False          0.0        0.0
# 38868                        The Viking  False          0.0        0.0
# 16167                        The Viking  False          0.0        0.0
# 9327                        The Warrior  False          6.3       15.0
# 8068                        The Warrior  False          6.3       15.0
# 13220  Why We Fight: Divide and Conquer  False          5.0        1.0
# 35795  Why We Fight: Divide and Conquer  False          5.0        1.0
#
# [34 rows x 24 columns]

# %% [markdown]
# ### Handling Missing Values

# %%
# Check missing values
data1.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    28853
# budget                       0
# genres                       0
# homepage                 25849
# id                           0
# imdb_id                     11
# original_language            0
# original_title               0
# overview                    64
# popularity                   0
# poster_path                311
# production_companies         0
# production_countries         0
# release_date                59
# revenue                      0
# runtime                      6
# spoken_languages             0
# status                       0
# tagline                  14122
# title                        0
# video                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
# Fill null values in tagline column with "No Tagline"
data1['tagline'] = data1['tagline'].fillna("No Tagline")
data1
# Out:
# C:\Users\Josua\AppData\Local\Temp\ipykernel_11912\3601506307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['tagline'] = data1['tagline'].fillna("No Tagline")
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45456   True                                                NaN         0
# 45457   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45456           [{'id': 878, 'name': 'Science Fiction'}]
# 45457  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45456                                   NaN  222848  tt0112613
# 45457                                   NaN   30840  tt0102797
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# 45462                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45456                en              Caged Heat 3000
# 45457                en                   Robin Hood
# 45460                en                     Betrayal
# 45461                en          Satana likuyushchiy
# 45462                en                     Queerama
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4      Just when George Banks has recovered from his ...  ...    1995-02-10
# ...                                                  ...  ...           ...
# 45456  It's the year 3000 AD. The world's most danger...  ...    1995-01-01
# 45457  Yet another version of the classic epic, with ...  ...    1991-05-13
# 45460  When one of her hits goes wrong, a professiona...  ...    2003-08-01
# 45461  In a small town live two brothers, one a minis...  ...    1917-10-21
# 45462  50 years after decriminalisation of homosexual...  ...    2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45456          0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45457          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45460          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    87.0                                                 []
# 45462          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                         No Tagline
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45456  Released                                         No Tagline
# 45457  Released                                         No Tagline
# 45460  Released                             A deadly game of wits.
# 45461  Released                                         No Tagline
# 45462  Released                                         No Tagline
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45456              Caged Heat 3000  False          3.5        1.0
# 45457                   Robin Hood  False          5.7       26.0
# 45460                     Betrayal  False          3.8        6.0
# 45461             Satan Triumphant  False          0.0        0.0
# 45462                     Queerama  False          0.0        0.0
#
# [31952 rows x 24 columns]

# %%
# Drop all missing values
data2 = data1.dropna()
data2
# Out:
#        adult                              belongs_to_collection     budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 9       True  {'id': 645, 'name': 'James Bond Collection', '...   58000000
# 68      True  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000
# 69      True  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000
# 153     True  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000
# ...      ...                                                ...        ...
# 44366   True  {'id': 69788, 'name': 'Sharpe Collection', 'po...          0
# 44477   True  {'id': 2794, 'name': 'The Chronicles of Riddic...          0
# 44671   True  {'id': 476961, 'name': 'Goon Collection', 'pos...          0
# 44839   True  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 45007   True  {'id': 463112, 'name': 'Hailey Dean Mystery Co...          0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 9      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                        [{'id': 35, 'name': 'Comedy'}]
# 69     [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                       [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 44366  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44477  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 44671                     [{'id': 35, 'name': 'Comedy'}]
# 44839  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 45007  [{'id': 10770, 'name': 'TV Movie'}, {'id': 964...
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 9           http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 68         http://www.newline.com/properties/friday.html   10634  tt0113118
# 69     http://www.miramax.com/movie/from-dusk-till-dawn/     755  tt0116367
# 153           http://miramax.com/movie/blue-in-the-face/    5894  tt0112541
# ...                                                  ...     ...        ...
# 44366                  http://www.sharpefilm.com/rifles/   70133  tt0108108
# 44477              http://www.thechroniclesofriddick.com    2791  tt0407658
# 44671         https://www.facebook.com/GoonFilm/?fref=ts  336890  tt2417712
# 44839                  http://www.transformersmovie.com/  335988  tt3371366
# 45007  http://www.hallmarkmoviesandmysteries.com/hail...  422842  tt6203026
#
#       original_language                          original_title  \
# 0                    en                               Toy Story
# 9                    en                               GoldenEye
# 68                   en                                  Friday
# 69                   en                     From Dusk Till Dawn
# 153                  en                        Blue in the Face
# ...                 ...                                     ...
# 44366                en                         Sharpe's Rifles
# 44477                en    The Chronicles of Riddick: Dark Fury
# 44671                en             Goon: Last of the Enforcers
# 44839                en           Transformers: The Last Knight
# 45007                en  Hailey Dean Mystery: Murder, With Love
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 9      James Bond must unmask the mysterious head of ...  ...    1995-11-16
# 68     Craig and Smokey are two guys in Los Angeles h...  ...    1995-04-26
# 69     Seth Gecko and his younger brother Richard are...  ...    1996-01-19
# 153    Auggie runs a small tobacco shop in Brooklyn, ...  ...    1995-09-15
# ...                                                  ...  ...           ...
# 44366  During the Peninsular War in Spain against the...  ...    1993-05-05
# 44477  After their narrow escape at the end of "Pitch...  ...    2004-06-15
# 44671  During a pro lockout, Doug "The Thug" Glatt is...  ...    2017-03-17
# 44839  Autobots and Decepticons are at war, with huma...  ...    2017-06-21
# 45007  Former prosecutor-turned-therapist Hailey Dean...  ...    2016-10-23
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 68      28215918.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 69      25836616.0   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 153      1275000.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 44366          0.0   102.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 44477          0.0    34.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 44671          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 44839  604942143.0   149.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45007          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                         No Tagline
# 9      Released               No limits. No fears. No substitutes.
# 68     Released  A lot can go down between thursday and saturda...
# 69     Released  One night is all that stands between them and ...
# 153    Released                    Welcome to the planet Brooklyn.
# ...         ...                                                ...
# 44366  Released                                         No Tagline
# 44477  Released                                         No Tagline
# 44671  Released                                      Glatt's Back!
# 44839  Released         For one world to live, the other must die.
# 45007  Released                                         No Tagline
#
#                                         title  video vote_average vote_count
# 0                                   Toy Story  False          7.7     5415.0
# 9                                   GoldenEye  False          6.6     1194.0
# 68                                     Friday  False          7.0      513.0
# 69                        From Dusk Till Dawn  False          6.9     1644.0
# 153                          Blue in the Face  False          6.8       28.0
# ...                                       ...    ...          ...        ...
# 44366                         Sharpe's Rifles  False          5.6       27.0
# 44477    The Chronicles of Riddick: Dark Fury  False          5.9      157.0
# 44671             Goon: Last of the Enforcers  False          6.0       35.0
# 44839           Transformers: The Last Knight  False          6.2     1440.0
# 45007  Hailey Dean Mystery: Murder, With Love  False          6.0        1.0
#
# [759 rows x 24 columns]

# %%
# Check data2 info
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 759 entries, 0 to 45007
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  759 non-null    bool
#  1   belongs_to_collection  759 non-null    object
#  2   budget                 759 non-null    int64
#  3   genres                 759 non-null    object
#  4   homepage               759 non-null    object
#  5   id                     759 non-null    int64
#  6   imdb_id                759 non-null    object
#  7   original_language      759 non-null    object
#  8   original_title         759 non-null    object
#  9   overview               759 non-null    object
#  10  popularity             759 non-null    float64
#  11  poster_path            759 non-null    object
#  12  production_companies   759 non-null    object
#  13  production_countries   759 non-null    object
#  14  release_date           759 non-null    datetime64[ns]
#  15  revenue                759 non-null    float64
#  16  runtime                759 non-null    float64
#  17  spoken_languages       759 non-null    object
#  18  status                 759 non-null    object
#  19  tagline                759 non-null    object
#  20  title                  759 non-null    object
#  21  video                  759 non-null    bool
#  22  vote_average           759 non-null    float64
#  23  vote_count             759 non-null    float64
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(2), object(14)
# memory usage: 137.9+ KB

# %%
# Check null value in data2
data2.isnull().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %% [markdown]
# ## Study Case

# %% [markdown]
# ### 1. 10 Films released and highest vote

# %%
release_movie = data2[data2['status']=='Released'].sort_values(by='vote_count', ascending=True)
release_movie.head(10)
# Out:
#        adult                              belongs_to_collection  budget  \
# 35534   True  {'id': 98448, 'name': 'Thou Shalt Laugh Collec...       0
# 35535   True  {'id': 98448, 'name': 'Thou Shalt Laugh Collec...       0
# 35536   True  {'id': 98448, 'name': 'Thou Shalt Laugh Collec...       0
# 42764   True  {'id': 129626, 'name': 'The Pub Landlord Colle...       0
# 15244   True  {'id': 435347, 'name': '男はつらいよ シリーズ', 'poster_...       0
# 37616   True  {'id': 263866, 'name': "Nuke 'Em High Collecti...       0
# 45007   True  {'id': 463112, 'name': 'Hailey Dean Mystery Co...       0
# 40791   True  {'id': 418326, 'name': 'Signed, Sealed, Delive...       0
# 38334   True  {'id': 134063, 'name': 'Animation Runner Kurom...       0
# 40568   True  {'id': 163798, 'name': 'Gumball 3000 Collectio...       0
#
#                                                   genres  \
# 35534                     [{'id': 35, 'name': 'Comedy'}]
# 35535                     [{'id': 35, 'name': 'Comedy'}]
# 35536                     [{'id': 35, 'name': 'Comedy'}]
# 42764                     [{'id': 35, 'name': 'Comedy'}]
# 15244                     [{'id': 35, 'name': 'Comedy'}]
# 37616  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 45007  [{'id': 10770, 'name': 'TV Movie'}, {'id': 964...
# 40791  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 38334                                                 []
# 40568  [{'id': 99, 'name': 'Documentary'}, {'id': 12,...
#
#                                                 homepage      id    imdb_id  \
# 35534                     http://www.thoushaltlaugh.com/   98440  tt1320113
# 35535                     http://www.thoushaltlaugh.com/   98438  tt0907868
# 35536                     http://www.thoushaltlaugh.com/   98439  tt1128079
# 42764                         http://thepublandlord.com/   40748  tt0965457
# 15244         http://www.tora-san.jp/toranomaki/movie08/  253232  tt0067540
# 37616                      http://return2nukeemhigh.com/  207680  tt3039472
# 45007  http://www.hallmarkmoviesandmysteries.com/hail...  422842  tt6203026
# 40791  http://www.hallmarkmoviesandmysteries.com/sign...  361261  tt5084214
# 38334  http://www.absoluteanime.com/animation_runner_...   87636  tt1728601
# 40568                        http://www.gumball3000.com/   35701  tt0390067
#
#       original_language                                     original_title  \
# 35534                en                                 Thou Shalt Laugh 3
# 35535                en                                   Thou Shalt Laugh
# 35536                en                     Thou Shalt Laugh 2 - The Deuce
# 42764                en  Al Murray, The Pub Landlord - Glass of White W...
# 15244                en                Otoko wa tsurai yo: Torajiro koiuta
# 37616                en    Return to Return to Nuke 'Em High, aka Volume 2
# 45007                en             Hailey Dean Mystery: Murder, With Love
# 40791                en    Signed, Sealed, Delivered: The Impossible Dream
# 38334                en               Animation Seisaku Shinkō Kuromi-chan
# 40568                en                            Gumball 3000: The Movie
#
#                                                 overview  ...  release_date  \
# 35534  New from the #1 family comedy series of all-ti...  ...    2008-11-04
# 35535  Seven of the funniest Christian Comedians on e...  ...    2006-11-07
# 35536  Hot on the heels of the hit DVD Thou Shalt Lau...  ...    2007-11-07
# 42764  Al Murray's Pub Landlord puts the world to rig...  ...    2004-11-22
# 15244  Taking a message from Hiroshi's father to hear...  ...    1971-12-29
# 37616  Following the events of Volume 1,  the mutated...  ...    2017-01-15
# 45007  Former prosecutor-turned-therapist Hailey Dean...  ...    2016-10-23
# 40791  The Postables work against the clock decoding ...  ...    2015-10-04
# 38334  After being inspired by the fictional anime, "...  ...    2001-03-30
# 40568  A 3000 mile race from San Francisco to Miami t...  ...    2003-01-01
#
#       revenue runtime                          spoken_languages    status  \
# 35534     0.0    94.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 35535     0.0    93.0                                        []  Released
# 35536     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 42764     0.0    64.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15244     0.0   114.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 37616     0.0    72.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45007     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40791     0.0    84.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 38334     0.0    40.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 40568     0.0    98.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 35534  The Next PRETTY-MUCH-PERFECT Installment in th...
# 35535                                         No Tagline
# 35536  Seven of the funniest Christian Comedians on e...
# 42764                                         No Tagline
# 15244                                         No Tagline
# 37616                                         No Tagline
# 45007                                         No Tagline
# 40791                                         No Tagline
# 38334                                         No Tagline
# 40568                      6 Days. 150 Cars. 3000 Miles.
#
#                                                    title  video vote_average  \
# 35534                                 Thou Shalt Laugh 3  False          0.0
# 35535                                   Thou Shalt Laugh  False          0.0
# 35536                     Thou Shalt Laugh 2 - The Deuce  False          0.0
# 42764  Al Murray, The Pub Landlord - Glass of White W...  False          0.0
# 15244                               Tora-san's Love Call  False          0.0
# 37616    Return to Return to Nuke 'Em High, aka Volume 2  False          0.0
# 45007             Hailey Dean Mystery: Murder, With Love  False          6.0
# 40791    Signed, Sealed, Delivered: The Impossible Dream  False          6.0
# 38334                            Animation Runner Kuromi  False          6.5
# 40568                            Gumball 3000: The Movie  False          6.0
#
#       vote_count
# 35534        0.0
# 35535        0.0
# 35536        0.0
# 42764        0.0
# 15244        0.0
# 37616        0.0
# 45007        1.0
# 40791        1.0
# 38334        1.0
# 40568        1.0
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 2. Film with duration length more than 3 hours

# %%
data2[data2['runtime'] > 3]
# Out:
#        adult                              belongs_to_collection     budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 9       True  {'id': 645, 'name': 'James Bond Collection', '...   58000000
# 68      True  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000
# 69      True  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000
# 153     True  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000
# ...      ...                                                ...        ...
# 44366   True  {'id': 69788, 'name': 'Sharpe Collection', 'po...          0
# 44477   True  {'id': 2794, 'name': 'The Chronicles of Riddic...          0
# 44671   True  {'id': 476961, 'name': 'Goon Collection', 'pos...          0
# 44839   True  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 45007   True  {'id': 463112, 'name': 'Hailey Dean Mystery Co...          0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 9      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                        [{'id': 35, 'name': 'Comedy'}]
# 69     [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                       [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 44366  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44477  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 44671                     [{'id': 35, 'name': 'Comedy'}]
# 44839  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 45007  [{'id': 10770, 'name': 'TV Movie'}, {'id': 964...
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 9           http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 68         http://www.newline.com/properties/friday.html   10634  tt0113118
# 69     http://www.miramax.com/movie/from-dusk-till-dawn/     755  tt0116367
# 153           http://miramax.com/movie/blue-in-the-face/    5894  tt0112541
# ...                                                  ...     ...        ...
# 44366                  http://www.sharpefilm.com/rifles/   70133  tt0108108
# 44477              http://www.thechroniclesofriddick.com    2791  tt0407658
# 44671         https://www.facebook.com/GoonFilm/?fref=ts  336890  tt2417712
# 44839                  http://www.transformersmovie.com/  335988  tt3371366
# 45007  http://www.hallmarkmoviesandmysteries.com/hail...  422842  tt6203026
#
#       original_language                          original_title  \
# 0                    en                               Toy Story
# 9                    en                               GoldenEye
# 68                   en                                  Friday
# 69                   en                     From Dusk Till Dawn
# 153                  en                        Blue in the Face
# ...                 ...                                     ...
# 44366                en                         Sharpe's Rifles
# 44477                en    The Chronicles of Riddick: Dark Fury
# 44671                en             Goon: Last of the Enforcers
# 44839                en           Transformers: The Last Knight
# 45007                en  Hailey Dean Mystery: Murder, With Love
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 9      James Bond must unmask the mysterious head of ...  ...    1995-11-16
# 68     Craig and Smokey are two guys in Los Angeles h...  ...    1995-04-26
# 69     Seth Gecko and his younger brother Richard are...  ...    1996-01-19
# 153    Auggie runs a small tobacco shop in Brooklyn, ...  ...    1995-09-15
# ...                                                  ...  ...           ...
# 44366  During the Peninsular War in Spain against the...  ...    1993-05-05
# 44477  After their narrow escape at the end of "Pitch...  ...    2004-06-15
# 44671  During a pro lockout, Doug "The Thug" Glatt is...  ...    2017-03-17
# 44839  Autobots and Decepticons are at war, with huma...  ...    2017-06-21
# 45007  Former prosecutor-turned-therapist Hailey Dean...  ...    2016-10-23
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 68      28215918.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 69      25836616.0   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 153      1275000.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 44366          0.0   102.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 44477          0.0    34.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 44671          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 44839  604942143.0   149.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45007          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                         No Tagline
# 9      Released               No limits. No fears. No substitutes.
# 68     Released  A lot can go down between thursday and saturda...
# 69     Released  One night is all that stands between them and ...
# 153    Released                    Welcome to the planet Brooklyn.
# ...         ...                                                ...
# 44366  Released                                         No Tagline
# 44477  Released                                         No Tagline
# 44671  Released                                      Glatt's Back!
# 44839  Released         For one world to live, the other must die.
# 45007  Released                                         No Tagline
#
#                                         title  video vote_average vote_count
# 0                                   Toy Story  False          7.7     5415.0
# 9                                   GoldenEye  False          6.6     1194.0
# 68                                     Friday  False          7.0      513.0
# 69                        From Dusk Till Dawn  False          6.9     1644.0
# 153                          Blue in the Face  False          6.8       28.0
# ...                                       ...    ...          ...        ...
# 44366                         Sharpe's Rifles  False          5.6       27.0
# 44477    The Chronicles of Riddick: Dark Fury  False          5.9      157.0
# 44671             Goon: Last of the Enforcers  False          6.0       35.0
# 44839           Transformers: The Last Knight  False          6.2     1440.0
# 45007  Hailey Dean Mystery: Murder, With Love  False          6.0        1.0
#
# [757 rows x 24 columns]
